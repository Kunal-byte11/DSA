# %% [markdown]
# <a href="https://colab.research.google.com/github/Kunal-byte11/DSA/blob/main/ml-exps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#exp3
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

y_actual = [1,0,1,1,1]
y_pred=[1,0,0,1,0]

print("Precision:-", precision_score(y_actual,y_pred))
print("Accuracy:-", accuracy_score(y_actual,y_pred))
print("Recall:-", recall_score(y_actual, y_pred))
print("F1:-", f1_score(y_actual,y_pred))
# Out:
# Precision:- 1.0
# Accuracy:- 0.6
# Recall:- 0.5
# F1:- 0.6666666666666666

# %%
#exp4
from sklearn.linear_model import LinearRegression

import matplotlib.pyplot as plt

X = [[1],[2],[3],[4]]

y=[2,4,6,8]

model = LinearRegression()
model.fit(X,y)
pred = model.predict(X)

plt.scatter(X,y)
plt.plot(X,pred)
plt.show()

# %%
# Exp5
from sklearn.linear_model import LogisticRegression

import matplotlib.pyplot as plt

X = [[1],[2],[3],[4]]
y=[0,0,1,1]

model = LogisticRegression()

model.fit(X,y)

pred = model.predict(X)

plt.scatter(X,y)
plt.plot(X,pred)
plt.show()

# %%
#exp6
import numpy as np

A = np.array([[1,2],[3,4]])

U,S,Vt = np.linalg.svd(A)

print("U",U)
# Out:
# U [[-0.40455358 -0.9145143 ]
#  [-0.9145143   0.40455358]]

# %%
#exp6 for img

import numpy as np

from skimage import data

import matplotlib.pyplot as plt

img = data.camera()
U,S,Vt = np.linalg.svd(img)
k=50
img_k=U[:,:k] @np.diag(S[:k])@ Vt[:k,:]
plt.imshow(img_k,cmap='gray')
plt.axis('off')
plt.show()

# %%
#exp7
from sklearn import datasets
from sklearn.svm import SVC
import matplotlib.pyplot as plt

# Load dataset
data = datasets.load_iris()
X = data.data[:, :2]
y = data.target

# Model
model = SVC(kernel='linear')
model.fit(X, y)

# Plot
plt.scatter(X[:,0], X[:,1], c=y)
plt.title("SVM Classification")
plt.show()

# %%
#exp8
import numpy as np

# Input patterns
X = np.array([[1,1], [1,-1], [-1,1], [-1,-1]])

# Target output
y = np.array([1, -1, -1, 1])

# Initialize weights
w = np.zeros(2)

# Hebb Learning
for i in range(len(X)):
    w = w + X[i] * y[i]

print("Final Weights:", w)

# %%
#exp9
import numpy as np
import matplotlib.pyplot as plt

# Data
X = np.array([[1,1], [1,-1], [-1,1], [-1,-1]])
y = np.array([1, -1, -1, -1])

# Train
w = np.zeros(2)
for _ in range(10):
    for i in range(len(X)):
        if y[i] * (np.dot(w, X[i])) <= 0:
            w = w + y[i] * X[i]

# Plot points
for i in range(len(X)):
    if y[i] == 1:
        plt.scatter(X[i][0], X[i][1])
    else:
        plt.scatter(X[i][0], X[i][1])

# Decision boundary
x_vals = np.linspace(-2, 2)
y_vals = -(w[0]*x_vals)/w[1]

plt.plot(x_vals, y_vals)
plt.title("Perceptron Decision Boundary")
plt.show()

# %%
#exp10
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# Data
data = load_iris()
X = data.data
y = data.target

# PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Plot
plt.scatter(X_pca[:,0], X_pca[:,1], c=y)
plt.title("PCA")
plt.show()
